# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
t = np.arange(0,100,1e-2)
data = 10*np.exp(-0.03*t)*np.cos(t)
data = data.reshape(-1,1)
plt.figure(figsize=(15,15))
plt.xlabel("t")
plt.ylabel("x(t)")
plt.grid()
plt.title("Damped harmonic oscillator")
plt.plot(t,data[:])
plt.show()
